# %% [markdown]
# # 1. 课程总览
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 什么是机器人？
#  - “ A robot is an
# autonomous system
# which exists in the
# physical world,
# can sense its environment, and
# can act on it to
# achieve some goals.”
#  - 机器人是一个自主系统，它存在于物理世界中，可以感知其环境，并可以对其采取行动以实现一些目标。

# %% [markdown]
# 怎么实现人机交互？
#
#  - 机器人行动的总体流程见下图：
#  - ![image.png](attachment:image.png)

# %% [markdown]
# 根据上图，本课程的内容分布：
#
# ![image.png](attachment:image.png)
